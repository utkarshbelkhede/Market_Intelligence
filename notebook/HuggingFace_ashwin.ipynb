# %%
import pandas as pd

# %%
tesla = pd.read_csv("https://raw.githubusercontent.com/utkarshbelkhede/Market_Intelligence/master/tesla.csv")
tesla = tesla.iloc[:,1:]
tesla.head()
# Out:
#   Company  Reporting_Date                                                 1A  \
# 0    tsla        20211231   ITEM 1A.RISK FACTORS You should carefully con...
# 1    tsla        20201231   ITEM 1A. RISK FACTORSYou should carefully con...
# 2    tsla        20191231   ITEM 1A. RISK FACTORSYou should carefully con...
# 3    tsla        20171231   I TEM 1A. RISK FACTORS You should carefully c...
# 4    tsla        20181231   ITEM 1A. RI SK FACTORS You should carefully c...
#
#                                           1B  \
# 0   ITEM 1B.UNRESOLVED STAFF COMMENTS None.
# 1    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
# 2    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
# 3    I TEM 1B. UNRESOLVED STAFF COMMENTSNone
# 4    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
#
#                                                    3  \
# 0   ITEM 3.LEGAL PROCEEDINGS For a description of...
# 1   ITEM 3. LEGA L PROCEEDINGS For a description ...
# 2   ITEM 3. LEGAL PROCEEDINGSFor a description of...
# ...

# %%
# !pip install transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 21.3 MB/s
# ...

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization', model="human-centered-summarization/financial-summarization-pegasus", device=0)

# %%
tesla.iloc[0,4]
# Out:
# " ITEM 3.LEGAL PROCEEDINGS For a description of our material pending legal proceedings, please see Note 15, Commitments and Contingencies , to the consolidated financial statements included elsewhere in this Annual Report on Form 10-K. In addition, each of the matters below is being disclosed pursuant to Item 103 of Regulation S-K because it relates to environmental regulations and aggregate civil penalties that we currently believe could potentially exceed $1 million. We believe that any proceeding that is material to our business or financial condition is likely to have potential penalties far in excess of such amount. The German Umweltbundesamt has issued our subsidiary in Germany a notice and fine in the amount of 12 million euro alleging its non-compliance under applicable laws relating to market participation notifications and take-back obligations with respect to end-of-life battery products required thereunder. In response to Teslas objection, the German Umweltbundesamt issue
# ...

# %%
summarizer(tesla.iloc[0,4], max_length=200, min_length=50, do_sample=False)
# Out:
# [{'summary_text': 'Tesla has disclosed in this Annual Report on Form 10-K certain matters that it believes could potentially exceed $1 million. Tesla has also disclosed in this Annual Report on Form 10-K certain matters that it believes could potentially exceed $1 million on an aggregate basis.'}]

# %%
summarizer = pipeline('summarization', model="nsi319/legal-led-base-16384", tokenizer="nsi319/legal-led-base-16384", device=0)
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/648M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
summarizer(tesla.iloc[0,4], max_length=300, min_length=50, do_sample=False)
# Out:
# [{'summary_text': "On May 24, 2020, the Securities and Exchange Commission filed an emergency action against Tesla, charging the company with non-compliance under applicable federal regulations and imposing a $1 million civil penalty.  The SEC's complaint, filed in federal court in California, alleges that Tesla failed to provide records demonstrating compliance with certain requirements under the applicable National Emission Standards for Hazardous Air Pollutants under the Clean Air Act of 1963.  Tesla has agreed to cooperate with the SEC in resolving the matter.  The SEC's complaint alleges that Tesla failed to provide records demonstrating compliance with certain requirements under the applicable National Emission Standards for Hazardous Air Pollutants under the Clean Air Act.  Tesla has also agreed to cooperate with the U.S. Attorney's Office for the District of California and to pay a $1 million penalty.  The SEC's complaint charges Tesla with violating the antifraud provisions 
# ...

# %%
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
classifier(tesla.iloc[0,4])
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9912785887718201}]

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/496M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
tokenizer(tesla.iloc[0,4])
# Out:
# {'input_ids': [0, 3779, 5330, 155, 4, 3850, 534, 2118, 36352, 39857, 10942, 286, 10, 8194, 9, 84, 1468, 5319, 1030, 7069, 6, 2540, 192, 6068, 379, 6, 36886, 2963, 8, 7555, 154, 14768, 2156, 7, 5, 14436, 613, 1997, 1165, 5140, 11, 42, 7453, 2872, 15, 8575, 158, 12, 530, 4, 96, 1285, 6, 349, 9, 5, 3510, 874, 16, 145, 4638, 22918, 7, 39870, 13156, 9, 18912, 208, 12, 530, 142, 24, 16009, 7, 3039, 3478, 8, 13884, 2366, 6736, 14, 52, 855, 679, 115, 2905, 11514, 68, 134, 153, 4, 166, 679, 14, 143, 19635, 14, 16, 1468, 7, 84, 265, 50, 613, 1881, 16, 533, 7, 33, 801, 6736, 444, 11, 7400, 9, 215, 1280, 4, 20, 1859, 12698, 605, 6607, 428, 3194, 293, 424, 90, 34, 1167, 84, 8540, 11, 1600, 10, 3120, 8, 2051, 11, 5, 1280, 9, 316, 153, 2287, 11537, 63, 786, 12, 33182, 223, 10404, 2074, 8941, 7, 210, 5740, 16926, 8, 185, 12, 1644, 9333, 19, 2098, 7, 253, 12, 1116, 12, 5367, 3822, 785, 1552, 89, 5087, 4, 96, 1263, 7, 13462, 15086, 24763, 6, 5, 1859, 12698, 605, 6607, 428, 3194, 293, 424, 90, 1167, 49
# ...
