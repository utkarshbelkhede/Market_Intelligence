# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Setting the default path
import os
import sys
sys.path.append('/content/drive/MyDrive/Market Intelligence')

# %%
import pandas as pd

# %%
tesla = pd.read_csv("/content/drive/MyDrive/Market Intelligence/datasets/tesla.csv")
tesla = tesla.iloc[:,1:]
tesla.head()
# Out:
#   Company  Reporting_Date                                                 1A  \
# 0    tsla        20211231   ITEM 1A.RISK FACTORS You should carefully con...
# 1    tsla        20201231   ITEM 1A. RISK FACTORSYou should carefully con...
# 2    tsla        20191231   ITEM 1A. RISK FACTORSYou should carefully con...
# 3    tsla        20171231   I TEM 1A. RISK FACTORS You should carefully c...
# 4    tsla        20181231   ITEM 1A. RI SK FACTORS You should carefully c...
#
#                                           1B  \
# 0   ITEM 1B.UNRESOLVED STAFF COMMENTS None.
# 1    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
# 2    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
# 3    I TEM 1B. UNRESOLVED STAFF COMMENTSNone
# 4    ITEM 1B. UNRESOLVED STAFF COMMENTSNone.
#
#                                                    3  \
# 0   ITEM 3.LEGAL PROCEEDINGS For a description of...
# 1   ITEM 3. LEGA L PROCEEDINGS For a description ...
# 2   ITEM 3. LEGAL PROCEEDINGSFor a description of...
# ...

# %%
tesla.rename(columns = {'Reporting_Date': 'Year', '1A':'Risk Factor', '1B':'Unresolved Staff Comments', '3':'Legal Proceedings', '5':'Market for Registrant’s Common Equity', '7':'Management’s Discussion and Analysis', '7A':'Quantitative and Qualitative Disclosures about Market Risk'}, inplace = True)

# %%
20211231 // 10000
# Out:
# 2021

# %%
tesla['Year'] = tesla['Year'] // 10000

# %%
del tesla['Unresolved Staff Comments']

# %%
tesla.head()
# Out:
#   Company  Year                                        Risk Factor  \
# 0    tsla  2021   ITEM 1A.RISK FACTORS You should carefully con...
# 1    tsla  2020   ITEM 1A. RISK FACTORSYou should carefully con...
# 2    tsla  2019   ITEM 1A. RISK FACTORSYou should carefully con...
# 3    tsla  2017   I TEM 1A. RISK FACTORS You should carefully c...
# 4    tsla  2018   ITEM 1A. RI SK FACTORS You should carefully c...
#
#                                    Legal Proceedings  \
# 0   ITEM 3.LEGAL PROCEEDINGS For a description of...
# 1   ITEM 3. LEGA L PROCEEDINGS For a description ...
# 2   ITEM 3. LEGAL PROCEEDINGSFor a description of...
# 3   I TEM 3. LEGAL PROCEEDINGSProceedings Related...
# 4   I TEM 3. LEGA L PROCEEDINGSFor a description ...
#
#                Market for Registrant’s Common Equity  \
# 0   ITEM 5. MARKET FOR REGISTRANTS COMMO N EQUITY...
# 1   ITEM 5. MARKET FOR REGISTRANTS COMMON EQUITY,...
# 2   I TEM 5. MARKET FOR REGISTRANTS COMMON EQUITY...
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
def text_summarizer(text):
  sumr = summarizer(text, max_length=100, min_length=5, do_sample=False)
  
  return sumr[0]['summary_text']

# %%
risk_factor = tesla.loc[:,'Risk Factor'].tolist()

# %%
text_summarizer(tesla.iloc[0,3])
# Out:
# ' Each of the matters below is being disclosed pursuant to Item 103 of Regulation S-K because it relates to environmental regulations and aggregate civil penalties that we currently believe could potentially exceed $1 million . We believe that any proceeding that is material to our business or financial condition is likely to have potential penalties far in excess of such amount . The German Umweltbundesamt has issued Tesla a notice and fine in the amount of 12 million euro alleging its non-compliance .'

# %%
column = ['Risk Factor', 'Unresolved Staff Comments', 'Legal Proceedings', 'Market for Registrant’s Common Equity', 'Management’s Discussion and Analysis', 'Quantitative and Qualitative Disclosures about Market Risk']

# %%
tesla.iloc[0, 2]
# Out:
# " ITEM 1A.RISK FACTORS You should carefully consider the risks described below together with the other information set forth in this report, which could materially affect our business, financial condition and future results. The risks described below are not the only risks facing our company. Risks and uncertainties not currently known to us or that we currently deem to be immaterial also may materially adversely affect our business, financial condition and operating results. Risks Related to Our Ability to Grow Our Business We may be impacted by macroeconomic conditions resulting from the global COVID-19 pandemic. Since the first quarter of 2020, there has been a worldwide impact from the COVID-19 pandemic. Government regulations and shifting social behaviors have limited or closed non-essential transportation, government functions, business activities and person-to-person interactions. In some cases, the relaxation of such trends has been followed by actual or contemplated returns 
# ...

# %%
s = summarizer(tesla.iloc[0,4], max_length=1000, min_length=50, do_sample=False)
# Out:
# Your max_length is set to 1000, but you input_length is only 676. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=338)

# %%
s[0]['summary_text']
# Out:
# " Tesla's stock has traded on The NASDAQ Global Select Market under the symbol TSLA since it began trading on June 29, 2010 . Our initial public offering was priced at $3.40 per share . We have never declared or paid cash dividends on our common stock . We do not anticipate paying any cash dividends in the foreseeable future ."

# %% [markdown]
# Tesla's stock has traded on The NASDAQ Global Select Market under the symbol TSLA since it began trading on June 29, 2010 . Our initial public offering was priced at $3.40 per share . We have never declared or paid cash dividends on our common stock . We do not anticipate paying any cash dividends in the foreseeable future .

# %%
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
tesla.iloc[0,4]
# Out:
# ' ITEM 5. MARKET FOR REGISTRANTS COMMO N EQUITY, RELATED STOCKHOLDER MATTERS AND ISSUER PURCHASES OF EQUITY SECURITIES Market Information Our common stock has traded on The NASDAQ Global Select Market under the symbol TSLA since it began trading on June 29, 2010. Our initial public offering was priced at $3.40 per share on June 28, 2010 as adjusted to give effect to the five-for-one stock split effected in the form of a stock dividend in August 2020 . Holders As of January 31, 2022, there were 7,051 holders of record of our common stock. A substantially greater number of holders of our common stock are street name or beneficial holders, whose shares are held by banks, brokers and other financial institutions. Dividend Policy We have never declared or paid cash dividends on our common stock. We currently do not anticipate paying any cash dividends in the foreseeable future. Any future determination to declare cash dividends will be made at the discretion of our board of directors, sub
# ...

# %%
classifier(tesla.iloc[0,4], padding=True, truncation=True)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9979310035705566}]

# %%
from transformers import TFAutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"

# %%
model = TFAutoModelForQuestionAnswering.from_pretrained(model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForQuestionAnswering.
#
# All the layers of TFRobertaForQuestionAnswering were initialized from the model checkpoint at deepset/roberta-base-squad2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForQuestionAnswering for predictions without further training.

# %%
question = pipeline('question-answering', model=model_name, tokenizer=model_name)
# Out:
# {'score': 0.09725451469421387, 'start': 498, 'end': 503, 'answer': '7,051'}

# %%
QA_input = {
    'question': 'How many Holders were there?',
    'context': tesla.iloc[0,4]
}
answer = question(QA_input)
answer
# Out:
# {'score': 0.09725451469421387, 'start': 498, 'end': 503, 'answer': '7,051'}

# %%
zero_shot_classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# %%
sequence_to_classify = tesla.iloc[0,4]

candidate_labels = ['environmental', 'fraud', 'regulations']

zero_shot_classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': ' ITEM 5. MARKET FOR REGISTRANTS COMMO N EQUITY, RELATED STOCKHOLDER MATTERS AND ISSUER PURCHASES OF EQUITY SECURITIES Market Information Our common stock has traded on The NASDAQ Global Select Market under the symbol TSLA since it began trading on June 29, 2010. Our initial public offering was priced at $3.40 per share on June 28, 2010 as adjusted to give effect to the five-for-one stock split effected in the form of a stock dividend in August 2020 . Holders As of January 31, 2022, there were 7,051 holders of record of our common stock. A substantially greater number of holders of our common stock are street name or beneficial holders, whose shares are held by banks, brokers and other financial institutions. Dividend Policy We have never declared or paid cash dividends on our common stock. We currently do not anticipate paying any cash dividends in the foreseeable future. Any future determination to declare cash dividends will be made at the discretion of our board of d
# ...
